# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import pathlib

# %%
data_dir = pathlib.Path("images/")
data_dir
# Out:
# WindowsPath('images')

# %%
print([i for i in data_dir.glob('*/train')])
data_dir.glob('*/train')
# Out:
# [WindowsPath('images/Chicken Rice/train'), WindowsPath('images/Testing/train')]
# <generator object Path.glob at 0x0000020658E98BA0>

# %%
image_count = len(list(data_dir.glob('*/*/*/*.jpg')))
image_count
# Out:
# 720

# %%
roasted_imgs = list(data_dir.glob('Chicken Rice/*/Roasted/*.jpg'))
print(len(roasted_imgs))
PIL.Image.open(roasted_imgs[2])
# Out:
# 360
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=705x705 at 0x206583E3E80>

# %%
steamed_imgs = list(data_dir.glob('Chicken Rice/*/Steamed/*.jpg'))
print(len(steamed_imgs))
PIL.Image.open(steamed_imgs[2])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x1080 at 0x206585CF8B0>

# %%
batch_size = 32
img_height = 180
img_width = 180

train_ds = tf.keras.utils.image_dataset_from_directory(
  pathlib.Path("images/Chicken Rice/train"),
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [43], in <cell line: 5>()
#       2 img_height = 180
#       3 img_width = 180
# ----> 5 train_ds = tf.keras.utils.image_dataset_from_directory(
#       6   pathlib.Path("images/Chicken Rice/train"),
#       7   subset="training",
#       8   seed=123,
#       9   image_size=(img_height, img_width),
#      10   batch_size=batch_size)
#
# File C:\Anaconda3\lib\site-packages\keras\utils\image_dataset.py:187, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, **kwargs)
#     183   raise ValueError(
#     184       '`color_mode` must be one of {"rgb", "rgba", "grayscale"}. '
#     185       f'Received: color_mode={color_mode}')
# ...
